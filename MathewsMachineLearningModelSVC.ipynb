# %% [markdown]
# ## Mathews notebook for Machine Learning SVC modeling

# %%
# Load Modules

# Python package for plotting charts
import matplotlib.pyplot as plt
# Python package for dataframe creation and manipulation
import pandas as pd
# Python package for low level math functions
import numpy as np
# Python package for third party operating systems
import os
# Python package for statistical modeling: split dataset
from sklearn.model_selection import train_test_split
# Python package for statistical modeling: support vector classifier
from sklearn.svm import SVC 
# Python package for statistical modeling: 
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# %%
# Read File

honeybee_csv = pd.read_csv(os.path.join('Resources', 'Output', 'HoneybeeDatasetSVCModel.csv'))
honeybee_csv.head()
# Out:
#    Region  FIPS  ColonyCount  ColonyGrowth  GrowthOutcome  TotalProduction  \
# 0       3     1        16000           NaN            NaN           928000
# 1       3     1        15000         -6.25            0.0           960000
# 2       3     1        14000         -6.67            0.0           924000
# 3       3     1        16000         14.29            1.0          1136000
# 4       3     1        17000          6.25            1.0          1156000
#
#    YieldPerColony  PricePerLB  ProductionValue  Stocks  YearRecorded  \
# 0              58        0.69           640000   28000          1995
# 1              64        0.87           835000   96000          1996
# 2              66        0.81           748000   92000          1997
# 3              71        0.72           818000  159000          1998
# 4              68        0.56           647000  185000          1999
#
#    ClothianidinLB  ImidaclopridLB  ThiamethoxamLB  AcetamipridLB  \
# 0             0.0         1579.61             0.0            0.0
# 1             0.0          819.24             0.0            0.0
# 2             0.0        14781.55             0.0            0.0
# 3             0.0         4048.35             0.0            0.0
# 4             0.0         2758.42             0.0            0.0
#
#    ThiaclopridLB  CombinedNeonicLB
# 0            0.0           1579.61
# 1            0.0            819.24
# 2            0.0          14781.55
# 3            0.0           4048.35
# 4            0.0           2758.42

# %%
# Drop NaN Rows

honeybee_csv = honeybee_csv.apply(pd.to_numeric, errors='coerce')
honeybee_csv = honeybee_csv.dropna()
honeybee_csv.head()
# Out:
#    Region  FIPS  ColonyCount  ColonyGrowth  GrowthOutcome  TotalProduction  \
# 1       3     1        15000         -6.25            0.0           960000
# 2       3     1        14000         -6.67            0.0           924000
# 3       3     1        16000         14.29            1.0          1136000
# 4       3     1        17000          6.25            1.0          1156000
# 5       3     1        16000         -5.88            0.0          1248000
#
#    YieldPerColony  PricePerLB  ProductionValue  Stocks  YearRecorded  \
# 1              64        0.87           835000   96000          1996
# 2              66        0.81           748000   92000          1997
# 3              71        0.72           818000  159000          1998
# 4              68        0.56           647000  185000          1999
# 5              78        0.59           736000  187000          2000
#
#    ClothianidinLB  ImidaclopridLB  ThiamethoxamLB  AcetamipridLB  \
# 1             0.0          819.24             0.0            0.0
# 2             0.0        14781.55             0.0            0.0
# 3             0.0         4048.35             0.0            0.0
# 4             0.0         2758.42             0.0            0.0
# 5             0.0         3305.17             0.0            0.0
#
#    ThiaclopridLB  CombinedNeonicLB
# 1            0.0            819.24
# 2            0.0          14781.55
# 3            0.0           4048.35
# 4            0.0           2758.42
# 5            0.0           3305.17

# %%
# Target Outcome Column

target = honeybee_csv['GrowthOutcome']
target_names = ['Growth', 'No-Growth']

# %%
# Drop Column

honeybee_data = honeybee_csv.drop(['GrowthOutcome', 'ColonyGrowth', 'YearRecorded', 'Region', 'FIPS'], axis=1)
honeybee_names = honeybee_data.columns
honeybee_data.head()
# Out:
#    ColonyCount  TotalProduction  YieldPerColony  PricePerLB  ProductionValue  \
# 1        15000           960000              64        0.87           835000
# 2        14000           924000              66        0.81           748000
# 3        16000          1136000              71        0.72           818000
# 4        17000          1156000              68        0.56           647000
# 5        16000          1248000              78        0.59           736000
#
#    Stocks  ClothianidinLB  ImidaclopridLB  ThiamethoxamLB  AcetamipridLB  \
# 1   96000             0.0          819.24             0.0            0.0
# 2   92000             0.0        14781.55             0.0            0.0
# 3  159000             0.0         4048.35             0.0            0.0
# 4  185000             0.0         2758.42             0.0            0.0
# 5  187000             0.0         3305.17             0.0            0.0
#
#    ThiaclopridLB  CombinedNeonicLB
# 1            0.0            819.24
# 2            0.0          14781.55
# 3            0.0           4048.35
# 4            0.0           2758.42
# 5            0.0           3305.17

# %%
# Split Data

x_train, x_test, y_train, y_test = train_test_split(honeybee_data, target, random_state=42)

# %%
# Scale Data

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
# scaler = StandardScaler().fit(x_train)
# x_train_scaled = scaler.transform(x_train)
# x_test_scaled = scaler.transform(x_test)

# %%
# Create SVC Classifier

honeybee_svc_model = SVC(kernel='rbf', cache_size=5000)
#.fit(x_train, y_train)

# %%
# Fit Model

honeybee_svc_model.fit(x_train, y_train)
# Out:
# SVC(cache_size=5000)

# %%
# SVC Model Accuracy

print(f'Test accuracy: %.3f' % honeybee_svc_model.score(x_test, y_test))
# Out:
# Test accuracy: 0.683

# %%
# Calculate Report

honeybee_prediction = honeybee_svc_model.predict(x_test)
print(classification_report(y_test, honeybee_prediction,
                            target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#       Growth       0.68      0.97      0.80       146
#    No-Growth       0.71      0.15      0.25        78
#
#     accuracy                           0.68       224
#    macro avg       0.69      0.56      0.53       224
# weighted avg       0.69      0.68      0.61       224
