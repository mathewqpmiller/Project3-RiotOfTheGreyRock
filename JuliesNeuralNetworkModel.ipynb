# %% [markdown]
# ## Julie's notebook for Neural Network modeling

# %%
# Load Modules
# Set seed value so results are reproducible
from numpy.random import seed
seed(42)
import numpy as np

# Python package for dataframe creation and manipulation
import pandas as pd
# Python package for third party operating systems
import os

# Package for modeling and scaling
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.neural_network import MLPClassifier

# Packages for one hot encoding
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Read File
honeybee_csv = pd.read_csv(os.path.join('Resources', 'Data', 'growth_designation.csv'))

# %%
# Create a function to run through model

def Fct1(df):
    X = df.drop(["GrowthOutcome"],axis=1)
    y = df["GrowthOutcome"]
    print(X.shape,y.shape)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    X_scaler = StandardScaler().fit(X_train)
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    y_train_categorical = to_categorical(y_train)
    y_test_categorical = to_categorical(y_test)
    NN_model = Sequential()
    number_hidden_nodes = 4
    NN_model.add(Dense(units=12,
                activation='relu', input_dim=12))
    number_classes = 2
    NN_model.add(Dense(units=number_classes, activation='softmax'))
    NN_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    NN_model.fit(
    X_train_scaled,
    y_train_categorical, epochs=500, shuffle=True, verbose=2)
    model_loss, model_accuracy = NN_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
    return (model_loss, model_accuracy)
#     print(f"Pest 1 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Scenario 1: All
model_loss, model_accuracy = Fct1(honeybee_csv)
# print(f"Scenario 1 (All) Training Data Score: {classifier.score(X1_train, y1_train)}")
# print(f"Scenario 1 (All) Testing Data Score: {classifier.score(X1_test, y1_test)}")
print(f"Scenario 1 (All) Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# (895, 12) (895,)
# Train on 671 samples
# Epoch 1/500
# 671/671 - 0s - loss: 0.7591 - accuracy: 0.5976
# Epoch 2/500
# 671/671 - 0s - loss: 0.7217 - accuracy: 0.6140
# Epoch 3/500
# 671/671 - 0s - loss: 0.6951 - accuracy: 0.6200
# Epoch 4/500
# 671/671 - 0s - loss: 0.6767 - accuracy: 0.6274
# Epoch 5/500
# 671/671 - 0s - loss: 0.6647 - accuracy: 0.6364
# Epoch 6/500
# 671/671 - 0s - loss: 0.6565 - accuracy: 0.6349
# Epoch 7/500
# 671/671 - 0s - loss: 0.6507 - accuracy: 0.6393
# Epoch 8/500
# 671/671 - 0s - loss: 0.6475 - accuracy: 0.6349
# Epoch 9/500
# 671/671 - 0s - loss: 0.6448 - accuracy: 0.6408
# Epoch 10/500
# 671/671 - 0s - loss: 0.6427 - accuracy: 0.6483
# Epoch 11/500
# 671/671 - 0s - loss: 0.6409 - accuracy: 0.6468
# Epoch 12/500
# 671/671 - 0s - loss: 0.6393 - accuracy: 0.6498
# Epoch 13/500
# 671/671 - 0s - loss: 0.6383 - accuracy: 0.6498
# Epoch 14/500
# 671/671 - 0s - loss: 0.6368 - accuracy: 0.6528
# Epoch 15/500
# 671/671 - 0s - loss: 0.6360 - accuracy: 0.6513
# ...

# %%
X_train_scaled
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a6393b5efdca> in <module>
# ----> 1 X_train_scaled
#
# NameError: name 'X_train_scaled' is not defined

# %%
clf = MLPClassifier(solver='adam', 
                    alpha=1e-5,
                    hidden_layer_sizes=(6,), 
                    random_state=1)

clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-8c7e4d14117e> in <module>
#       4                     random_state=1)
#       5
# ----> 6 clf.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
predictions_train = clf.predict(X_train_scaled)
predictions_test = clf.predict(X_test_scaled)
train_score = accuracy_score(predictions_train, train_labels)
print("score on train data: ", X_train_scaled)
test_score = accuracy_score(predictions_test, test_labels)
print("score on train data: ", predictions_train)

# %%
# Create a function to run through model

def Fct2_3(df):
    X = df.drop(["GrowthOutcome"],axis=1)
    y = df["GrowthOutcome"]
    print(X.shape,y.shape)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    X_scaler = StandardScaler().fit(X_train)
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    y_train_categorical = to_categorical(y_train)
    y_test_categorical = to_categorical(y_test)
    NN_model = Sequential()
    number_hidden_nodes = 4
    NN_model.add(Dense(units=6,
                activation='relu', input_dim=6))
    number_classes = 2
    NN_model.add(Dense(units=number_classes, activation='softmax'))
    NN_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    NN_model.fit(
    X_train_scaled,
    y_train_categorical, epochs=500, shuffle=True, verbose=2)
    model_loss, model_accuracy = NN_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
    return (model_loss, model_accuracy)
#     print(f"Pest 1 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Scenario 2: ProductionValue, TotalProduction, ImidaclopridLB, Stocks, PricePerLB (top five from random forest model)
Scen2_df = honeybee_csv.drop(['YieldPerColony', 'Clothianidin', 'Thiamethoxam', 'Acetamiprid', 'Thiacloprid', 'CombinedNeonic'],axis=1)
model_loss, model_accuracy = Fct2_3(Scen2_df)
print(f"Scenario 2 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
columns = list(honeybee_csv)
columns

# %%
# Scenario 3: Just all pesticides exdluding combined
Scen3_df = honeybee_csv.drop([ 'Clothianidin', 'Imidacloprid', 'Thiamethoxam', 'Acetamiprid', 'Thiacloprid', 'CombinedNeonic'],axis=1)
model_loss, model_accuracy = Fct2_3(Scen3_df)
print(f"Scenario 3 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
columns = list(honeybee_csv)
columns

# %%
# Create a function to run through model

def Fct4(df):
    X = df.drop(["GrowthOutcome"],axis=1)
    y = df["GrowthOutcome"]
    print(X.shape,y.shape)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    X_scaler = StandardScaler().fit(X_train)
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    y_train_categorical = to_categorical(y_train)
    y_test_categorical = to_categorical(y_test)
    NN_model = Sequential()
    number_hidden_nodes = 4
    NN_model.add(Dense(units=11,
                activation='relu', input_dim=11))
    number_classes = 2
    NN_model.add(Dense(units=number_classes, activation='softmax'))
    NN_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    NN_model.fit(
    X_train_scaled,
    y_train_categorical, epochs=500, shuffle=True, verbose=2)
    model_loss, model_accuracy = NN_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
    return (model_loss, model_accuracy)
#     print(f"Pest 1 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Scenario 4: Just combined pesticide
Scen4_df = honeybee_csv.drop(['CombinedNeonic'],axis=1)
model_loss, model_accuracy = Fct4(Scen4_df)
print(f"Scenario 3 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Create a function to run through model

def Fct5(df):
    X = df.drop(["GrowthOutcome"],axis=1)
    y = df["GrowthOutcome"]
    print(X.shape,y.shape)
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
    X_scaler = StandardScaler().fit(X_train)
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)
    y_train_categorical = to_categorical(y_train)
    y_test_categorical = to_categorical(y_test)
    NN_model = Sequential()
    number_hidden_nodes = 4
    NN_model.add(Dense(units=11,
                activation='relu', input_dim=11))
    number_classes = 2
    NN_model.add(Dense(units=number_classes, activation='softmax'))
    NN_model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    NN_model.fit(
    X_train_scaled,
    y_train_categorical, epochs=500, shuffle=True, verbose=2)
    model_loss, model_accuracy = NN_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
    return (model_loss, model_accuracy)
#     print(f"Pest 1 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Scenario 5: ColonyCount, TotalProduction, YieldPerColony, PricePerLB, ProductionValue, Stocks (excludes the pesticides)
Scen5_df = honeybee_csv.drop(['ColonyCount',
 'TotalProduction',
 'YieldPerColony',
 'PricePerLB',
 'ProductionValue',
 'Stocks'],axis=1)
model_loss, model_accuracy = Fct4(Scen4_df)
print(f"Scenario 3 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
columns = list(honeybee_csv)
columns

# %%
# Pest1v2_df = honeybee_csv.drop(["Imidacloprid","Thiamethoxam","Acetamiprid","Thiacloprid","CombinedNeonic"],axis=1)
# model_loss, model_accuracy = Pestv2(Pest1v2_df)
# print(f"Pest 1 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Pest2v2_df = honeybee_csv.drop(["Imidacloprid","Thiamethoxam","Acetamiprid","Thiacloprid","CombinedNeonic"],axis=1)
# model_loss, model_accuracy = Pestv2(Pest2v2_df)
# print(f"Pest  Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Pest3v2_df = honeybee_csv.drop(["Clothianidin","Imidacloprid","Acetamiprid","Thiacloprid","CombinedNeonic"],axis=1)
# model_loss, model_accuracy = Pestv2(Pest3v2_df)
# print(f"Pest 3 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Pest4v2_df = honeybee_csv.drop(["Clothianidin","Imidacloprid","Thiamethoxam","Thiacloprid","CombinedNeonic"],axis=1)
# model_loss, model_accuracy = Pestv2(Pest4v2_df)
# print(f"Pest 4 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Pest5v2_df = honeybee_csv.drop(["Clothianidin","Imidacloprid","Thiamethoxam","Acetamiprid","CombinedNeonic"],axis=1)
# model_loss, model_accuracy = Pestv2(Pest5v2_df)
# print(f"Pest 5 Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# PestAllv2_df = honeybee_csv.drop(["Clothianidin","Imidacloprid","Thiamethoxam","Acetamiprid","Thiacloprid"],axis=1)
# model_loss, model_accuracy = Pestv2(PestAllv2_df)
# print(f"Pest 5 Loss: {model_loss}, Accuracy: {model_accuracy}")
