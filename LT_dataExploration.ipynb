# %%
import pandas as pd

# %%
raw_data = pd.read_csv("Resources/Data/vHoneyNeonic_v02.csv")
raw_data
# Out:
#     state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 0      AL  11000.0           56   616000.0  209000.0        1.49   918000.0
# 1      AL  11000.0           72   792000.0  230000.0        1.21   958000.0
# 2      AL  12000.0           86  1032000.0  103000.0        1.18  1218000.0
# 3      AL  12000.0           87  1044000.0  282000.0        1.41  1472000.0
# 4      AL  13000.0           66   858000.0  266000.0        1.02   875000.0
# ..    ...      ...          ...        ...       ...         ...        ...
# 820    WY  40000.0           68  2720000.0  190000.0        1.78  4842000.0
# 821    WY  43000.0           80  3440000.0  894000.0        1.00  3440000.0
# 822    WY  46000.0           60  2760000.0  524000.0        0.68  1877000.0
# 823    WY  47000.0           66  3102000.0  558000.0        2.11  6545000.0
# 824    WY  50000.0           51  2550000.0  459000.0        1.87  4769000.0
#
# ...

# %% [markdown]
# ### Brainstorming
#
# - convert state to a numeric value (necessary?)
# - convert neonic columns to boolean values - dummy encoding does the converstion of categorical data to boolean values and takes age groups and coverts them. Probably won't work for the format of the neonic data value.
# - <p style = "color: blue">set the max neonic value per row as the categorical value for y and use the numcol, yieldpercol, totalprod, stocks,priceperlb, prodvalue as features (X)</p>
# - <p style = "color: blue">set max neonic value per row as it's categorical value and then one hot encode to use it as a feature to predict region? state? categorically transformed priceperlb as above or below average over dataset?</p>

# %%
# import csv
# file_to_open = "Resources/Data/vHoneyNeonic_v02.csv"
# with open(file_to_open,'r')as this_csv_file:
#     this_csv_reader = csv.reader(this_csv_file, delimiter=',')
#     header = next(this_csv_reader)
#     print(header)
# Out:
# ['state', 'numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue', 'year', 'StateName', 'Region', 'nCLOTHIANIDIN', 'nIMIDACLOPRID', 'nTHIAMETHOXAM', 'nACETAMIPRID', 'nTHIACLOPRID', 'nAllNeonic']

# %%
raw_data.dtypes
# Out:
# state             object
# numcol           float64
# yieldpercol        int64
# totalprod        float64
# stocks           float64
# priceperlb       float64
# prodvalue        float64
# year               int64
# StateName         object
# Region            object
# nCLOTHIANIDIN    float64
# nIMIDACLOPRID    float64
# nTHIAMETHOXAM    float64
# nACETAMIPRID     float64
# nTHIACLOPRID     float64
# nAllNeonic       float64
# dtype: object

# %%
reduced_data = raw_data.dropna(how="any", axis=0)
reduced_data
# Out:
#     state   numcol  yieldpercol  totalprod    stocks  priceperlb  prodvalue  \
# 0      AL  11000.0           56   616000.0  209000.0        1.49   918000.0
# 1      AL  11000.0           72   792000.0  230000.0        1.21   958000.0
# 2      AL  12000.0           86  1032000.0  103000.0        1.18  1218000.0
# 3      AL  12000.0           87  1044000.0  282000.0        1.41  1472000.0
# 4      AL  13000.0           66   858000.0  266000.0        1.02   875000.0
# ..    ...      ...          ...        ...       ...         ...        ...
# 820    WY  40000.0           68  2720000.0  190000.0        1.78  4842000.0
# 821    WY  43000.0           80  3440000.0  894000.0        1.00  3440000.0
# 822    WY  46000.0           60  2760000.0  524000.0        0.68  1877000.0
# 823    WY  47000.0           66  3102000.0  558000.0        2.11  6545000.0
# 824    WY  50000.0           51  2550000.0  459000.0        1.87  4769000.0
#
# ...

# %% [markdown]
# ## Notes
#
# States not in dataset:
# - Alaska
# - Connecticut
# - Delaware
# - Michigan
# - New Hampshire
# - Rhode Island
#
# Hawaii has no data but space in the dataset
